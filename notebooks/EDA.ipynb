# %%
import os

import numpy as np
import pandas as pd

from pathlib import Path

with open("../data/02_intermediate/tidy_r1_score.csv") as score:
    r1_score = pd.read_csv(score, sep=",")

print(r1_score.groupby("Issue")["Score"].rank())
# Out:
# 0        9.0
# 1        8.0
# 2       11.0
# 3       15.0
# 4       20.0
#         ...
# 2203    10.0
# 2204    13.0
# 2205    16.0
# 2206    17.0
# 2207    18.0
# Name: Score, Length: 2208, dtype: float64
